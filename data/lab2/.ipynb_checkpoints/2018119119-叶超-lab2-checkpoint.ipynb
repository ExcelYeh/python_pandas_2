# %%
import pandas as pd
import os
import glob
import pprint

# %%
def get_idx(lists, flag):
    idx = 0
    while idx<len(temp) and temp[idx]!=char:
        idx+=1
    return idx

# %%
def get_char_last_index(strs, char):
    temp = strs[::-1]
    idx = 0
    while idx<len(temp) and temp[idx]!=char:
        idx+=1
    return (len(temp)-1-idx)

# %%
get_char_last_index(csv_file_list[0],'.')
# Out:
# 48

# %%
class CsvFile:
    def __init__(self, file_path):
        self.file_path =  file_path

# %%
class Solutions:
    '''
        csv文件处理
    '''
    def __init__(self, CsvFile):
        '''
            初始化函数，
            属性： CsvFile： CsvFile对象
        '''
        self.CsvFile =  CsvFile
    
        
    def get_idx(self, flag, lists):
        '''
            @brief：返回 flag 在lists第一次出现的下标
            @param: flag: 待寻找的元素
                    lists:集合
        '''
        idx = 0
        while idx<len(temp) and temp[idx]!=char:
            idx+=1
        return idx
    
    def get_last_index(self, flag, lists):
        '''
            获取 flag 在 lists 最后一次出现的下标
            思路： 反转字符串后， 寻找第一次出现的下标
        '''
        temp = strs[::-1]  # 反转字符串
        idx = get_idx(self, flag, temp)
        return (len(temp)-1-idx)
    
    def get_id_name(self):
        '''
            对属性 file_path 处理，得到csv文件对应的股票代码
        '''
        begin_char = '/'
        end_char = '.'
        begin_index = get_last_index(self.CsvFile.file_path, 
                                          begin_char) + 1
        end_index = get_last_index(self.CsvFile.file_path,
                                        end_char)
        return self.CsvFile.file_path[begin_index, end_index]
    
    
    def get_df(self):
        '''
            通过属性 file_path 处理csv数据，得到 DataFrame
        '''
        file = pd.read_csv(self.CsvFile.file_path)
        df = pd.DataFrame(file)
        return df
    
    def get_df_head_list(self):
        '''
            无参构造，得到列标题
        '''
        df = self.get_df()
        head_list = df.columns.values.tolist()
        return head_list
    
    def search_equal(self, head, val, show_head_list):
        
        '''
            寻找在 head 这一列中 值为 val的行，显示内容由 show_head_list 决定
        '''
        #-----------------------------------------
        '''
        df_head_list = self.get_df_head_list()
        head = df_head_list[head_idx]
        '''
        #-----------------------------------------
        df = self.get_df()
        return df.loc[ (df[head] == val), 
                show_head_list]
    def search_cmp(self,head, val, show_head_list):
        '''
            寻找在 head 这一列中 值> val的行，显示内容由 show_head_list 决定
        '''
        df = self.get_df()
        return df.loc[ (df[head] > val), 
                       show_head_list ]

# %%
def marge(csv_list, outputfile):
    for inputfile in csv_list:
        f = open(inputfile, 'r', encoding='gb18030',errors='ignore')
        data = pd.read_csv(f,encoding='gb18030')
        data.to_csv(outputfile, mode='a', index=False)
    print('完成合并')
 
 #去重保留一个表头
def distinct(file):
    df = pd.read_csv(file, header=None)
    datalist = df.drop_duplicates()
    datalist.to_csv( index=False, header=False)
    print('完成去重')

# %%
csv_list = glob.glob(os.getcwd()+'/data/*.csv')
output_csv_path = 'data/margin.csv'
print(csv_list)
marge(csv_list, output_csv_path)
distinct(output_csv_path)
# Out:
# ['/home/excel/python_program/data/lab2/data/600519.csv', '/home/excel/python_program/data/lab2/data/000858.csv']
# 完成合并
# 完成去重

# %% [markdown]
# ** <center>--------------------TEST---------------------</center> **

# %%
file_path = '/home/excel/python_program/data/lab2/data/margin.csv'

# %%
pd.DataFrame(pd.read_csv(file_path))
# Out:
#                日期     股票代码     名称      收盘价      最高价      最低价      开盘价  \
# 0      2020-09-21  '600519   贵州茅台   1666.8  1692.76  1666.66  1692.76
# 1      2020-09-18  '600519   贵州茅台   1695.0   1695.0  1635.01   1665.0
# 2      2020-09-17  '600519   贵州茅台  1670.52   1700.0   1658.0   1700.0
# 3      2020-09-16  '600519   贵州茅台   1725.1  1764.81   1719.0   1760.0
# 4      2020-09-15  '600519   贵州茅台   1760.0  1769.99  1747.75  1769.99
# ...           ...      ...    ...      ...      ...      ...      ...
# 10062  1998-05-04  '000858  五 粮 液    59.02    59.02     55.0     55.1
# 10063  1998-04-30  '000858  五 粮 液    53.65     54.2     53.2     53.3
# 10064  1998-04-29  '000858  五 粮 液     53.3    54.98     52.9    54.97
# 10065  1998-04-28  '000858  五 粮 液    54.19     56.5     53.6     54.0
# 10066  1998-04-27  '000858  五 粮 液    53.57     57.0    29.77    29.77
#
#            前收盘     涨跌额      涨跌幅      换手率       成交量           成交金额  \
# 0       1695.0   -28.2  -1.6637   0.1787   2244407   3756765108.0
# 1      1670.52   24.48   1.4654   0.3757   4720140   7853673241.0
# 2       1725.1  -54.58  -3.1639   0.5069   6367985  10683350187.0
# 3       1760.0   -34.9   -1.983   0.1792   2251598   3916457762.0
# 4       1766.0    -6.0  -0.3398   0.1657   2082087   3654872009.0
# ...        ...     ...      ...      ...       ...            ...
# 10062    53.65    5.37  10.0093   6.8347   4920974   285312925.33
# 10063     53.3    0.35   0.6567   3.3135   2385686   127942178.11
# 10064    54.19   -0.89  -1.6424   4.7128   3393230   181927515.95
# 10065    53.57    0.62   1.1574    9.397   6765827    371571836.1
# 10066      0.0    None     None  47.4487  34163076  1846204586.12
#
#                    总市值             流通市值
# 0      2093830493040.0  2093830493040.0
# 1      2129255271000.0  2129255271000.0
# 2      2098503548860.0  2098503548860.0
# 3      2167066824780.0  2167066824780.0
# 4      2210908128000.0  2210908128000.0
# ...                ...              ...
# 10062    18886400000.0     4249440000.0
# 10063    17168000000.0     3862800000.0
# 10064    17056000000.0     3837600000.0
# 10065    17340800000.0     3901680000.0
# 10066    17142400000.0     3857040000.0
#
# [10067 rows x 15 columns]

# %% [markdown]
# **<center>----------------TEST--------------</center>**

# %%
csv_list
# Out:
# ['/home/excel/python_program/data/lab2/data/margin.csv',
#  '/home/excel/python_program/data/lab2/data/600519.csv',
#  '/home/excel/python_program/data/lab2/data/000858.csv']

# %%
def get_file_list(path):
    '''
    给出
    '''
    # ['600519.csv', '000858.csv']
    path_file_short_list = os.listdir(path) 
    path_file_full_list  = []
    for files in path_file_list:
        path_file_full = os.path.join(path, files)
        path_file_full_list.append(path_file_full)
    return path_file_full_list

# %%
def main():
    csv_list = glob.glob(os.getcwd()+'/data/*.csv')
    margin_file_path = os.getcwd()+'/data/margin.csv'
    if margin_file_path not in csv_list:
        output_csv_path = 'data/margin.csv'
        marge(csv_list, output_csv_path)
        distinct(output_csv_path)
        pwd = os.getcwd()+'/data'    # csv文件所在目录
        csv_list = glob.glob(os.getcwd()+'/data/*.csv')
    print(csv_list)
    file = CsvFile(csv_list[0]) # 读取第一个csv文件，新建CsvFile对象，
    test = Solutions(file)
    show_list = test.get_df_head_list()
    pprint.pprint(test.get_df())
    print(test.search_equal('日期', '2020-09-17', show_list).head())

# %%
if __name__ =='__main__':
    main()
# Out:
# ['/home/excel/python_program/data/lab2/data/margin.csv', '/home/excel/python_program/data/lab2/data/600519.csv', '/home/excel/python_program/data/lab2/data/000858.csv']
#                日期     股票代码     名称      收盘价      最高价      最低价      开盘价  \
# 0      2020-09-21  '600519   贵州茅台   1666.8  1692.76  1666.66  1692.76
# 1      2020-09-18  '600519   贵州茅台   1695.0   1695.0  1635.01   1665.0
# 2      2020-09-17  '600519   贵州茅台  1670.52   1700.0   1658.0   1700.0
# 3      2020-09-16  '600519   贵州茅台   1725.1  1764.81   1719.0   1760.0
# 4      2020-09-15  '600519   贵州茅台   1760.0  1769.99  1747.75  1769.99
# ...           ...      ...    ...      ...      ...      ...      ...
# 10062  1998-05-04  '000858  五 粮 液    59.02    59.02     55.0     55.1
# 10063  1998-04-30  '000858  五 粮 液    53.65     54.2     53.2     53.3
# 10064  1998-04-29  '000858  五 粮 液     53.3    54.98     52.9    54.97
# 10065  1998-04-28  '000858  五 粮 液    54.19     56.5     53.6     54.0
# 10066  1998-04-27  '000858  五 粮 液    53.57     57.0    29.77    29.77
#
#            前收盘     涨跌额      涨跌幅      换手率       成交量           成交金额  \
# 0       1695.0   -28.2  -1.6637   0.1787   2244407   3756765108.0
# 1      1670.52   24.48   1.4654   0.3757   4720140   7853673241.0
# 2       1725.1  -54.58  -3.1639   0.5069   6367985  10683350187.0
# 3       1760.0   -34.9   -1.983   0.1792   2251598   3916457762.0
# 4       1766.0    -6.0  -0.3398   0.1657   2082087   3654872009.0
# ...        ...     ...      ...      ...       ...            ...
# 10062    53.65    5.37  10.0093   6.8347   4920974   285312925.33
# 10063     53.3    0.35   0.6567   3.3135   2385686   127942178.11
# 10064    54.19   -0.89  -1.6424   4.7128   3393230   181927515.95
# 10065    53.57    0.62   1.1574    9.397   6765827    371571836.1
# 10066      0.0    None     None  47.4487  34163076  1846204586.12
#
#                    总市值             流通市值
# 0      2093830493040.0  2093830493040.0
# 1      2129255271000.0  2129255271000.0
# 2      2098503548860.0  2098503548860.0
# 3      2167066824780.0  2167066824780.0
# 4      2210908128000.0  2210908128000.0
# ...                ...              ...
# 10062    18886400000.0     4249440000.0
# 10063    17168000000.0     3862800000.0
# 10064    17056000000.0     3837600000.0
# 10065    17340800000.0     3901680000.0
# 10066    17142400000.0     3857040000.0
#
# [10067 rows x 15 columns]
#               日期     股票代码     名称      收盘价     最高价     最低价     开盘价     前收盘  \
# 2     2020-09-17  '600519   贵州茅台  1670.52  1700.0  1658.0  1700.0  1725.1
# 4632  2020-09-17  '000858  五 粮 液   222.65   226.0   218.9  222.06  226.02
#
#          涨跌额      涨跌幅     换手率       成交量           成交金额              总市值  \
# 2     -54.58  -3.1639  0.5069   6367985  10683350187.0  2098503548860.0
# 4632   -3.37   -1.491  0.6007  22801632  5066620919.79   864240022313.0
#
#                  流通市值
# 2     2098503548860.0
# 4632   845171990208.0

# %%
file = CsvFile(csv_file_list[2])

# %%
test = Solutions(file)

# %%
show_list = test.get_df_head_list()

# %%
show_list
# Out:
# ['日期',
#  '股票代码',
#  '名称',
#  '收盘价',
#  '最高价',
#  '最低价',
#  '开盘价',
#  '前收盘',
#  '涨跌额',
#  '涨跌幅',
#  '换手率',
#  '成交量',
#  '成交金额',
#  '总市值',
#  '流通市值']

# %%
test.search_equal('日期', '2020-09-17', show_list)
# Out:
#            日期     股票代码    名称      收盘价     最高价     最低价     开盘价     前收盘     涨跌额  \
# 2  2020-09-17  '600519  贵州茅台  1670.52  1700.0  1658.0  1700.0  1725.1  -54.58
#
#        涨跌幅     换手率      成交量          成交金额           总市值          流通市值
# 2  -3.1639  0.5069  6367985  1.068335e+10  2.098504e+12  2.098504e+12

# %%
test.search_cmp('收盘价', 222.65, show_list)
# Out:
#               日期     股票代码    名称      收盘价      最高价      最低价      开盘价      前收盘  \
# 0     2020-09-21  '600519  贵州茅台  1666.80  1692.76  1666.66  1692.76  1695.00
# 1     2020-09-18  '600519  贵州茅台  1695.00  1695.00  1635.01  1665.00  1670.52
# 2     2020-09-17  '600519  贵州茅台  1670.52  1700.00  1658.00  1700.00  1725.10
# 3     2020-09-16  '600519  贵州茅台  1725.10  1764.81  1719.00  1760.00  1760.00
# 4     2020-09-15  '600519  贵州茅台  1760.00  1769.99  1747.75  1769.99  1766.00
# ...          ...      ...   ...      ...      ...      ...      ...      ...
# 3086  2008-01-16  '600519  贵州茅台   222.84   227.00   222.00   226.80   228.36
# 3087  2008-01-15  '600519  贵州茅台   228.36   230.55   224.40   224.40   224.12
# 3088  2008-01-14  '600519  贵州茅台   224.12   228.60   218.50   225.00   216.02
# 3097  2007-12-28  '600519  贵州茅台   230.00   230.10   217.77   221.60   224.85
# 3098  2007-12-27  '600519  贵州茅台   224.85   225.30   217.20   222.00   222.01
#
#          涨跌额      涨跌幅     换手率      成交量          成交金额           总市值  \
# 0      -28.2  -1.6637  0.1787  2244407  3.756765e+09  2.093830e+12
# 1      24.48   1.4654  0.3757  4720140  7.853673e+09  2.129255e+12
# 2     -54.58  -3.1639  0.5069  6367985  1.068335e+10  2.098504e+12
# 3      -34.9   -1.983  0.1792  2251598  3.916458e+09  2.167067e+12
# 4       -6.0  -0.3398  0.1657  2082087  3.654872e+09  2.210908e+12
# ...      ...      ...     ...      ...           ...           ...
# 3086   -5.52  -2.4172  0.5496  2241908  5.022369e+08  2.103164e+11
# 3087    4.24   1.8918  0.5222  2130322  4.861456e+08  2.155262e+11
# 3088     8.1   3.7497  1.0523  4292507  9.598822e+08  2.115245e+11
# 3097    5.15   2.2904  0.6528  2662799  6.004460e+08  2.170740e+11
# 3098    2.84   1.2792  0.5370  2190698  4.858990e+08  2.122134e+11
#
#               流通市值
# 0     2.093830e+12
# 1     2.129255e+12
# 2     2.098504e+12
# 3     2.167067e+12
# 4     2.210908e+12
# ...            ...
# 3086  9.090334e+10
# 3087  9.315512e+10
# 3088  9.142549e+10
# 3097  9.382412e+10
# 3098  9.172328e+10
#
# [1317 rows x 15 columns]

# %%
test.search_cmp('成交金额', 7853673241, show_list)
# Out:
#              日期     股票代码     名称     收盘价     最高价     最低价     开盘价     前收盘  \
# 9    2020-09-08  '000858  五 粮 液  221.93  229.35  217.60  227.14  226.89
# 11   2020-09-04  '000858  五 粮 液  230.22  234.00  226.27  234.00  238.64
# 39   2020-07-28  '000858  五 粮 液  214.00  216.94  204.67  205.89  204.10
# 41   2020-07-24  '000858  五 粮 液  201.39  208.95  198.00  208.00  210.07
# 45   2020-07-20  '000858  五 粮 液  201.68  208.50  191.01  205.50  205.39
# 46   2020-07-17  '000858  五 粮 液  205.39  209.70  195.00  195.00  201.56
# 47   2020-07-16  '000858  五 粮 液  201.56  221.05  201.56  221.00  223.95
# 48   2020-07-15  '000858  五 粮 液  223.95  226.00  217.60  219.00  220.90
# 49   2020-07-14  '000858  五 粮 液  220.90  225.33  212.03  218.30  218.20
# 50   2020-07-13  '000858  五 粮 液  218.20  225.00  207.00  207.00  207.00
# 158  2020-02-04  '000858  五 粮 液  114.50  120.00  109.00  109.00  113.54
# 249  2019-09-11  '000858  五 粮 液  129.26  135.60  128.68  135.00  137.25
# 299  2019-07-03  '000858  五 粮 液  123.91  130.29  122.14  127.00  128.00
#
#         涨跌额      涨跌幅     换手率       成交量          成交金额           总市值  \
# 9     -4.96  -2.1861  0.9407  35708526  7.906065e+09  8.614453e+11
# 11    -8.42  -3.5283  0.9771  37092062  8.495154e+09  8.936238e+11
# 39      9.9   4.8506  1.0129  38449712  8.143034e+09  8.306641e+11
# 41    -8.68   -4.132  1.0679  40538626  8.233915e+09  7.817170e+11
# 45    -3.71  -1.8063  1.1668  44290656  8.808311e+09  7.828427e+11
# 46     3.83   1.9002  1.3956  52976677  1.078587e+10  7.972435e+11
# 47   -22.39  -9.9978  1.8592  70573669  1.481795e+10  7.823769e+11
# 48     3.05   1.3807  0.9792  37169954  8.289624e+09  8.692861e+11
# 49      2.7   1.2374  1.1558  43873308  9.589877e+09  8.574472e+11
# 50     11.2   5.4106  1.2877  48880722  1.064870e+10  8.469669e+11
# 158    0.96   0.8455  1.8710  71021426  8.017646e+09  4.444441e+11
# 249   -7.99  -5.8215  1.8501  70230982  9.220352e+09  5.017367e+11
# 299   -4.09  -3.1953  1.8821  71443386  9.012423e+09  4.809700e+11
#
#              流通市值
# 9    8.424389e+11
# 11   8.739075e+11
# 39   8.123369e+11
# 41   7.644697e+11
# 45   7.655706e+11
# 46   7.796536e+11
# 47   7.651151e+11
# 48   8.501067e+11
# 49   8.385290e+11
# 50   8.282799e+11
# 158  4.346382e+11
# 249  4.906667e+11
# 299  4.703582e+11

# %%
csv_file_list[0]
# Out:
# '/home/excel/python_program/data/lab2/data/test'

# %% [markdown]
# ------------------------------
#
# ------------------------------

# %%
date = input()
dates = pd.to_datetime(date)

# %%
df.loc[
    (df[head[0]]==dates),
     [head[0],head[1],head[2],
      head[3],head[4],head[5],
      head[6]
     ]
    ].head()

# %% [markdown]
# class Solutions:
#     '''
#         csv文件处理
#     '''
#     def __init__(self, CsvFile):
#         '''
#             初始化函数，
#             属性： CsvFile： CsvFile对象
#         '''
#         self.file_path =  CsvFile
#
#
#     def get_idx(self, flag, lists):
#         '''
#             @brief：返回 flag 在lists第一次出现的下标
#             @param: flag: 待寻找的元素
#                     lists:集合
#         '''
#         idx = 0
#         while idx<len(temp) and temp[idx]!=char:
#             idx+=1
#         return idx
#
#     def get_last_index(self, flag, lists):
#         '''
#             获取 flag 在 lists 最后一次出现的下标
#             思路： 反转字符串后， 寻找第一次出现的下标
#         '''
#         temp = strs[::-1]  # 反转字符串
#         idx = get_idx(self, flag, temp)
#         return (len(temp)-1-idx)
#
#     def get_id_name(self):
#         begin_char = '/'
#         end_char = '.'
#         begin_index = get_last_index(self.file_path,
#                                           begin_char) + 1
#         end_index = get_last_index(self.file_path,
#                                         end_char)
#         return self.file_path[begin_index, end_index]
#
#
#     def get_df(self):
#         file = pd.read_csv(file_path,encoding='gb18030')
#         df = pd.DataFrame(data)
#         return df
#
#     def get_df_head_list(self):
#         df = self.get_df()
#         head_list = df.columns.values.tolist()
#         return head_list
#
#     def search(self, head_idx, val, show_head_list):
#         '''
#         i.选择一只股票，显示此股票在某个输入的日期的当日数据。
#         '''
#         df_head_list = self.get_df_head_list()
#         head = df_head_list[head_idx]
#         return df.loc[ (df[head] == val),
#                 show_head_list]
#
# file = CsvFile(csv_file_list[0])
#
# test = Lab2(file)
#
# show_list = test.get_df_head_list()
#
# show_list
#
# test.search(3, 222.65, show_list)
#
# csv_file_list[0]

# %%
csv_path = os.getcwd()+'/data/'

# %%
path_file_list =  os.listdir(csv_path)
csv_file_list = []

# %%
path_file_list =['test']+path_file_list

# %%
for files in path_file_list:
    file_path = os.path.join(csv_path, files)
    csv_file_list.append(file_path)

# %%
csv_file_list
# Out:
# ['/home/excel/python_program/data/lab2/data/test',
#  '/home/excel/python_program/data/lab2/data/600519.csv',
#  '/home/excel/python_program/data/lab2/data/000858.csv']

# %% [markdown]
# #### 目前已知csv文件名就是股票代码

# %%
path = get_file_list(csv_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6deaeec3e92b> in <module>()
# ----> 1 path = get_file_list(csv_path)
#
# NameError: name 'get_file_list' is not defined

# %%
df_list = []
for files in path:
    data = pd.read_csv(files,encoding='gb18030')
    df = pd.DataFrame(data)
    df_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a95a5317f960> in <module>()
#       1 df_list = []
# ----> 2 for files in path:
#       3     data = pd.read_csv(files,encoding='gb18030')
#       4     df = pd.DataFrame(data)
#       5     df_list.append(df)
#
# NameError: name 'path' is not defined

# %%
data_list[0]
# Out:
#               日期     股票代码    名称      收盘价      最高价      最低价      开盘价      前收盘  \
# 0     2020-09-21  '600519  贵州茅台  1666.80  1692.76  1666.66  1692.76  1695.00
# 1     2020-09-18  '600519  贵州茅台  1695.00  1695.00  1635.01  1665.00  1670.52
# 2     2020-09-17  '600519  贵州茅台  1670.52  1700.00  1658.00  1700.00  1725.10
# 3     2020-09-16  '600519  贵州茅台  1725.10  1764.81  1719.00  1760.00  1760.00
# 4     2020-09-15  '600519  贵州茅台  1760.00  1769.99  1747.75  1769.99  1766.00
# ...          ...      ...   ...      ...      ...      ...      ...      ...
# 4624  2001-08-31  '600519  贵州茅台    37.01    37.62    36.80    37.15    37.10
# 4625  2001-08-30  '600519  贵州茅台    37.10    37.51    36.00    36.28    36.38
# 4626  2001-08-29  '600519  贵州茅台    36.38    37.00    36.10    36.98    36.86
# 4627  2001-08-28  '600519  贵州茅台    36.86    37.00    34.61    34.99    35.55
# 4628  2001-08-27  '600519  贵州茅台    35.55    37.78    32.85    34.51    31.39
#
#          涨跌额      涨跌幅      换手率       成交量          成交金额           总市值  \
# 0      -28.2  -1.6637   0.1787   2244407  3.756765e+09  2.093830e+12
# 1      24.48   1.4654   0.3757   4720140  7.853673e+09  2.129255e+12
# 2     -54.58  -3.1639   0.5069   6367985  1.068335e+10  2.098504e+12
# 3      -34.9   -1.983   0.1792   2251598  3.916458e+09  2.167067e+12
# 4       -6.0  -0.3398   0.1657   2082087  3.654872e+09  2.210908e+12
# ...      ...      ...      ...       ...           ...           ...
# 4624   -0.09  -0.2426   3.2492   2323148  8.623124e+07  9.252500e+09
# 4625    0.72   1.9791   6.7151   4801306  1.775586e+08  9.275000e+09
# 4626   -0.48  -1.3022   7.4479   5325275  1.946896e+08  9.095000e+09
# 4627    1.31    3.685  18.1326  12964779  4.634631e+08  9.215000e+09
# 4628    4.16  13.2526  56.8277  40631800  1.410347e+09  8.887500e+09
#
#               流通市值
# 0     2.093830e+12
# 1     2.129255e+12
# 2     2.098504e+12
# 3     2.167067e+12
# 4     2.210908e+12
# ...            ...
# 4624  2.646215e+09
# 4625  2.652650e+09
# 4626  2.601170e+09
# 4627  2.635490e+09
# 4628  2.541825e+09
#
# [4629 rows x 15 columns]
